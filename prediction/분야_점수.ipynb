# %%
import pandas as pd
import numpy as np

import colorsys
import random
import platform

# %%
df = pd.read_csv('C:\\Users\\User\\Desktop\\혜원\\코알라유니브\\해커톤\\finished_petition.csv')

df
# Out:
#                                                     제목        청원수  \
# 0                          저희 아파트 경비아저씨의 억울함을 풀어주세요...    446,434
# 1    울산 초등학교 1학년 아이에게 팬티빨기 숙제내고 학생 사진에 '섹시팬티', '공주님...    225,764
# 2                               등교 개학 시기를 미루어주시기 바랍니다.    255,333
# 3    방송통신위원회는 방송의 공적 책임 방기하고  언론이기를 포기한 채널A와 TV조선의 ...    273,513
# 4                         렌트카 훔쳐 사망사고를 낸 10대 엄중 처벌해주세요  1,007,040
# ..                                                 ...        ...
# 128                          나경원 의원 평창올림픽 위원직을 파면시켜주세요    360,905
# 129           김보름, 박지우 선수의 자격박탈과 적폐 빙상연맹의 엄중 처벌을 청원합니다    614,127
# 130                          미성년자 성폭행 형량 올려주세요 종신형원합니다    233,842
# 131                                초.중.고 학교 페미니즘교육 의무화    213,219
# 132      정형식 판사에 대해서 이 판결과 그 동안 판결에 대한 특별 감사를 청원합니다!!!    252,969
#
#             카테고리         시작일         마감일  \
# 0         인권/성평등  2020-05-11  2020-06-10
# 1          육아/교육  2020-04-28  2020-05-28
# 2          육아/교육  2020-04-24  2020-05-24
# ...

# %%
df['카테고리'].value_counts()
# Out:
# 인권/성평등         31
# 정치개혁           20
# 기타             19
# 안전/환경          17
# 문화/예술/체육/언론    12
# 육아/교육          11
# 반려동물            6
# 교통/건축/국토        4
# 보건복지            4
# 행정              3
# 경제민주화           2
# 외교/통일/국방        2
# 미래              1
# 일자리             1
# Name: 카테고리, dtype: int64

# %%
names = list(set(df["카테고리"]))
for name in names:
    print(name, "의 분야점수 : ", len(df[df["카테고리"]==name]["카테고리"])/133)
# Out:
# 반려동물 의 분야점수 :  0.045112781954887216
# 문화/예술/체육/언론 의 분야점수 :  0.09022556390977443
# 일자리 의 분야점수 :  0.007518796992481203
# 보건복지 의 분야점수 :  0.03007518796992481
# 외교/통일/국방 의 분야점수 :  0.015037593984962405
# 기타 의 분야점수 :  0.14285714285714285
# 교통/건축/국토 의 분야점수 :  0.03007518796992481
# 안전/환경 의 분야점수 :  0.12781954887218044
# 정치개혁 의 분야점수 :  0.15037593984962405
# 인권/성평등 의 분야점수 :  0.23308270676691728
# 육아/교육 의 분야점수 :  0.08270676691729323
# 미래 의 분야점수 :  0.007518796992481203
# 경제민주화 의 분야점수 :  0.015037593984962405
# 행정 의 분야점수 :  0.022556390977443608

# %%
names = list(set(df["카테고리"]))
for name in names:
    score = len(df[df["카테고리"]==name]["카테고리"])/133
    print(name,"의 분야 점수 : ", "%0.4f" % score)
# Out:
# 반려동물 의 분야 점수 :  0.0451
# 문화/예술/체육/언론 의 분야 점수 :  0.0902
# 일자리 의 분야 점수 :  0.0075
# 보건복지 의 분야 점수 :  0.0301
# 외교/통일/국방 의 분야 점수 :  0.0150
# 기타 의 분야 점수 :  0.1429
# 교통/건축/국토 의 분야 점수 :  0.0301
# 안전/환경 의 분야 점수 :  0.1278
# 정치개혁 의 분야 점수 :  0.1504
# 인권/성평등 의 분야 점수 :  0.2331
# 육아/교육 의 분야 점수 :  0.0827
# 미래 의 분야 점수 :  0.0075
# 경제민주화 의 분야 점수 :  0.0150
# 행정 의 분야 점수 :  0.0226
